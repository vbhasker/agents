# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
gemini_api_key = os.getenv('GEMINI_API_KEY')

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Gemini API Key exists and begins AIzaSyCB

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from google import genai
from google.genai import types

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

client = genai.Client(api_key=gemini_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

# messages = [{"role": "user", "content": "What is 2+2?"}]

messages = types.Content(
  role='user',
  parts=[types.Part.from_text(text='What is 2+2?')]
)

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = client.models.generate_content(
    model='gemini-2.0-flash-001', contents=messages
)

print(response.text)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
# messages = [{"role": "user", "content": question}]
messages = types.Content(
  role='user',
  parts=[types.Part.from_text(text=question)]
)

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = client.models.generate_content(
    model='gemini-2.0-flash',
    contents=messages
)

question = response.text

print(question)
# Out:
# You have two jars, a 4-liter jar and a 5-liter jar. You want to measure out exactly 3 liters of water. You have access to a faucet that can provide an unlimited amount of water. How do you measure exactly 3 liters? Describe each step.

# %%
# form a new messages list
messages = types.UserContent(
  parts=[types.Part.from_text(text=question)]
)

# %%
# Ask it again

response = client.models.generate_content(
    model='gemini-2.5-flash-preview-05-20',
    contents=messages
)

answer = response.text
print(answer)
# Out:
# Here's how you can measure exactly 3 liters of water using a 4-liter jar and a 5-liter jar:
#
# **Steps:**
#
# 1.  **Fill the 4-liter jar completely.**
#     *   (4-liter jar: 4L, 5-liter jar: 0L)
#
# 2.  **Pour all the water from the 4-liter jar into the 5-liter jar.**
#     *   (4-liter jar: 0L, 5-liter jar: 4L)
#
# 3.  **Fill the 4-liter jar completely again.**
#     *   (4-liter jar: 4L, 5-liter jar: 4L)
#
# 4.  **Carefully pour water from the 4-liter jar into the 5-liter jar until the 5-liter jar is completely full.**
#     *   Since the 5-liter jar already has 4 liters, it only has space for 1 more liter. You will pour exactly 1 liter from the 4-liter jar into the 5-liter jar.
#     *   (4-liter jar: 4L - 1L = 3L, 5-liter jar: 4L + 1L = 5L)
#
# 5.  **You now have exactly 3 liters of water remaining in the 4-liter jar.** You can empty the 5-liter jar if you wish, or use the 3 liters from the 4-liter jar.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# This is a classic water measurement puzzle! Here's how to get exactly 3 liters:
#
# **Goal:** Measure 3 liters using a 4-liter jar and a 5-liter jar.
#
# **Steps:**
#
# 1.  **Fill the 4-liter jar completely.**
#     *   (4L jar: 4L, 5L jar: 0L)
#
# 2.  **Pour all the water from the 4-liter jar into the 5-liter jar.**
#     *   (4L jar: 0L, 5L jar: 4L)
#
# 3.  **Fill the 4-liter jar completely again.**
#     *   (4L jar: 4L, 5L jar: 4L)
#
# 4.  **Carefully pour water from the 4-liter jar into the 5-liter jar until the 5-liter jar is completely full.**
#     *   The 5-liter jar already has 4 liters, so it will only take 1 more liter to become full.
#     *   (4L jar: 3L remaining, 5L jar: 5L full)
#
# 5.  **You now have exactly 3 liters of water remaining in the 4-liter jar.**
#     *   You can empty the 5-liter jar if you no longer need the 5 liters.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = types.Content(
  role='user',
  parts=[types.Part.from_text(text='Give me a business idea for a startup that is a good fit for Agentic AI. Just give me the title of the business idea, no other text')]
)

# Then make the first call:

response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents=messages
)

# Then read the business idea:

business_idea = response.text

print(business_idea)

# And repeat!

challenge = types.Content(
  role='user',
  parts=[ types.Part.from_text(text=business_idea),
          types.Part.from_text(text='present the pain points of the business idea in a list of 5 items')]
)

response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents=challenge
)

print(response.text)

solution = types.Content(
  role='user',
  parts=[types.Part.from_text(text=business_idea),
         types.Part.from_text(text=response.text),
         types.Part.from_text(text='present the solution using the agentic AI business idea')]
)

response = client.models.generate_content(
    model='gemini-2.0-flash-001',
    contents=solution)

print(response.text)
# Out:
# Autonomous Marketing Campaign Optimization Platform
#
# Here are 5 potential pain points for an autonomous marketing campaign optimization platform:
#
# 1.  **"Black Box" Concerns & Lack of Transparency:** Users may be hesitant to fully trust an autonomous system if they don't understand *why* it's making specific decisions.  If the platform becomes a "black box" where actions are taken without clear explanations or insights, marketers may lose confidence, struggle to diagnose issues when campaigns underperform, and feel like they are losing control.  This lack of transparency makes it hard to learn from the system and improve future campaigns.
#
# 2.  **Initial Data & Training Requirements:**  A truly effective autonomous system needs a significant amount of historical data to train itself and accurately predict performance.  Businesses with limited marketing data, or data that is poorly structured, might struggle to get the platform up and running effectively.  This also creates a "chicken and egg" problem: the platform needs data to perform well, but businesses may hesitate to invest without proven results. It may also require significant time and resources to properly clean and format existing data.
#
# 3.  **Over-Optimization & Missing Nuance:** The platform might over-optimize for short-term metrics at the expense of long-term brand building or strategic objectives. An autonomous system could potentially miss important qualitative factors that a human marketer would consider, such as brand voice, target audience sensitivities, or emerging trends.  It's essential to ensure the platform aligns with the overall marketing strategy and doesn't inadvertently damage the brand in the pursuit of immediate results.
#
# 4.  **Integration Complexity & Technical Expertise:** Integrating the platform with existing marketing tools (CRM, analytics, advertising platforms, etc.) can be a significant challenge.  Businesses may need specialized technical expertise to ensure seamless data flow and avoid integration issues.  If the integration is complex or unreliable, it can create more work than it saves, negating the benefits of automation. Also, ensuring compatibility with future marketing technologies and platforms requires ongoing investment and updates.
#
# 5.  **Dealing with Unexpected Changes & Outliers:** The marketing landscape is constantly evolving, with new platforms, trends, and algorithms emerging regularly.  The platform needs to be robust enough to adapt to these unexpected changes and avoid making drastic decisions based on outlier data points.  Unexpected external events or market shifts could throw off the system's predictions and require human intervention to recalibrate. The platform must include mechanisms for anomaly detection and human override capabilities to mitigate potential risks.
#
# Okay, here's how we can address the pain points of an autonomous marketing campaign optimization platform using an Agentic AI approach. The core idea is to imbue the platform with intelligent, proactive agents that work collaboratively to solve these problems, offering a more transparent, adaptable, and user-friendly experience.
#
# **Agentic AI Solution: Introducing "SynergyAI" - The Agent-Driven Marketing Optimizer**
#
# SynergyAI isn't just an autonomous marketing platform; it's a team of specialized AI agents working in concert to optimize your campaigns with transparency, adaptability, and a focus on *your* strategic goals.
#
# Here's how SynergyAI tackles each pain point:
#
# **1. Addressing "Black Box" Concerns & Lack of Transparency: The "Insight Agent"**
#
# *   **Problem Addressed:** Users need to understand *why* the platform is making specific decisions.
# *   **Agentic Solution:**
#     *   **Insight Agent:** This agent is dedicated to providing clear, human-readable explanations for every optimization decision. It utilizes techniques like SHAP values and LIME to identify the key factors driving the platform's actions.
#     *   **Explainable AI (XAI) Module:** The Insight Agent interfaces with an XAI module that breaks down complex machine learning models into understandable components.
#     *   **Decision Audit Trail:** A complete, searchable audit trail of all decisions, complete with the Insight Agent's explanations, data sources, and confidence levels.
#     *   **"What-If" Analysis:** Users can simulate the impact of different decisions or scenarios, empowering them to understand the potential consequences of various strategies.
#     *   **Personalized Learning:** The Insight Agent learns the user's preferences and communicates insights in a way that is most understandable to them.
#
# **2. Solving Initial Data & Training Requirements: The "Data Sculptor Agent"**
#
# *   **Problem Addressed:**  Need for significant, well-structured historical data.
# *   **Agentic Solution:**
#     *   **Data Sculptor Agent:** This agent helps businesses overcome the "cold start" problem.
#     *   **Smart Data Connector:**  A library of pre-built connectors to common marketing tools, data warehouses, and cloud storage solutions.
#     *   **Automated Data Cleansing & Enrichment:** The agent identifies and corrects data quality issues (missing values, inconsistencies, outliers) and enriches existing data with external sources (demographic data, market trends).
#     *   **Transfer Learning & Meta-Learning:**  Utilizes pre-trained models based on industry best practices and publicly available datasets to accelerate learning and improve initial performance, even with limited data.
#     *   **Active Learning:** Identifies the most informative data points to request from the user, minimizing the data requirements while maximizing learning efficiency.
#     *   **Data Augmentation:** Generates synthetic data based on existing data, allowing the platform to be trained on a larger dataset, especially important for campaigns targeting niche demographics or utilizing emerging strategies.
#
# **3. Preventing Over-Optimization & Missing Nuance: The "Strategy Guardian Agent" & "Brand Sentinel Agent"**
#
# *   **Problem Addressed:**  Over-optimization for short-term metrics at the expense of long-term brand building and strategic objectives.
# *   **Agentic Solution:**
#     *   **Strategy Guardian Agent:** This agent acts as the gatekeeper, ensuring that all optimization decisions align with the user's overarching marketing strategy and key performance indicators (KPIs).
#         *   **Goal Alignment:**  Allows users to define and prioritize multiple, potentially conflicting goals (e.g., brand awareness, lead generation, customer lifetime value).
#         *   **Constraint Enforcement:** Enforces pre-defined constraints to prevent the platform from making decisions that violate ethical guidelines or brand standards.
#         *   **Scenario Planning:** Simulates long-term impacts of different optimization strategies, helping users choose the best path for sustainable growth.
#     *   **Brand Sentinel Agent:** This agent monitors online conversations, social media sentiment, and brand mentions to ensure that optimization decisions do not negatively impact brand reputation.
#         *   **Sentiment Analysis:** Continuously analyzes online sentiment to identify potential brand crises or negative feedback.
#         *   **Anomaly Detection:** Identifies unusual spikes in brand mentions or negative sentiment that may require human intervention.
#         *   **Brand Voice Consistency:** Ensures that all marketing communications generated by the platform are consistent with the brand's voice and values.
#
# **4. Simplifying Integration Complexity & Technical Expertise: The "Integration Architect Agent"**
#
# *   **Problem Addressed:** Integration with existing marketing tools can be complex and require specialized expertise.
# *   **Agentic Solution:**
#     *   **Integration Architect Agent:** This agent simplifies the integration process through intelligent automation.
#     *   **Auto-Discovery:** Automatically detects and identifies existing marketing tools within the user's ecosystem.
#     *   **No-Code Integration Interface:** Provides a drag-and-drop interface for connecting different tools, eliminating the need for complex coding.
#     *   **API Management:**  Handles API authentication, data mapping, and error handling automatically.
#     *   **Integration Monitoring:** Continuously monitors the health and performance of all integrations, alerting users to potential issues.
#     *   **Dynamic Adapter Generation:** Creates custom integration adapters for new or uncommon marketing tools on the fly.
#
# **5. Enhancing Response to Unexpected Changes & Outliers: The "Market Watcher Agent" & "Emergency Response Agent"**
#
# *   **Problem Addressed:** The platform needs to adapt to unexpected changes and outliers without making drastic decisions.
# *   **Agentic Solution:**
#     *   **Market Watcher Agent:** This agent continuously monitors the marketing landscape for emerging trends, new platforms, and algorithm updates.
#         *   **Trend Detection:** Identifies emerging trends and patterns in the data, alerting users to potential opportunities or threats.
#         *   **Algorithm Monitoring:** Tracks changes in search engine algorithms and social media platforms, adjusting optimization strategies accordingly.
#         *   **External Data Integration:** Integrates with external data sources (e.g., economic indicators, weather data) to account for external factors that may impact campaign performance.
#     *   **Emergency Response Agent:** This agent detects anomalies and outliers in the data and triggers appropriate actions.
#         *   **Anomaly Detection:** Employs statistical methods and machine learning to identify unusual data points that may indicate a problem.
#         *   **Human Override:**  Provides a mechanism for users to manually override the platform's decisions in critical situations.
#         *   **Adaptive Learning:**  Learns from past mistakes and adjusts its behavior to avoid making similar errors in the future.
#
# **SynergyAI: The Key Benefits**
#
# *   **Transparency:** Understand *why* the platform is making decisions.
# *   **Adaptability:**  Handles unexpected changes and outliers with ease.
# *   **Alignment:** Ensures that all optimization decisions are aligned with your strategic goals.
# *   **Efficiency:** Automates complex tasks and simplifies integration.
# *   **Control:** Empowers you to maintain control over your marketing campaigns.
# *   **Scalability:** Supports your marketing efforts as your business grows.
#
# **In Conclusion:**
#
# By adopting an Agentic AI approach, SynergyAI transforms an autonomous marketing campaign optimization platform from a "black box" into a team of intelligent agents that work collaboratively to help you achieve your marketing goals. This provides marketers with the transparency, adaptability, and control they need to succeed in today's ever-changing marketing landscape. This agent-driven approach builds trust, reduces risk, and maximizes the value of autonomous marketing optimization.
